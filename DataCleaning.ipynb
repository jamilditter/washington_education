# %%
import pandas as pd
import requests

# %%
url = 'https://data.wa.gov/resource/u4gd-6wxx.json'

response = requests.get(url)
data = response.json()

school_demo_2018 = pd.DataFrame(data)

# %%
url = 'https://data.wa.gov/resource/gtd3-scga.json'

response = requests.get(url)
data = response.json()

school_demo_2019 = pd.DataFrame(data)

# %%
url = 'https://data.wa.gov/resource/nvpc-yr7b.json'

response = requests.get(url)
data = response.json()

school_demo_2020 = pd.DataFrame(data)

# %%
url = 'https://data.wa.gov/resource/ymi4-syjv.json'

response = requests.get(url)
data = response.json()

school_demo_2021 = pd.DataFrame(data)

# %%
url = 'https://data.wa.gov/resource/dij7-mbxg.json'

response = requests.get(url)
data = response.json()

school_demo_2022 = pd.DataFrame(data)

# %%
url = 'https://data.wa.gov/resource/q4ba-s3jc.json'

response = requests.get(url)
data = response.json()

school_demo_2023 = pd.DataFrame(data)

# %%
url = 'https://data.wa.gov/resource/2rwv-gs2e.json'

response = requests.get(url)
data = response.json()

school_demo_2024 = pd.DataFrame(data)

# %%
url = 'https://data.wa.gov/resource/292v-tb9r.json'

response = requests.get(url)
data = response.json()

school_test_2014to2021 = pd.DataFrame(data)

# %%
url = 'https://data.wa.gov/resource/xh7m-utwp.json'

response = requests.get(url)
data = response.json()

school_test_2022 = pd.DataFrame(data)

# %%
url = 'https://data.wa.gov/resource/x73g-mrqp.json'

response = requests.get(url)
data = response.json()

school_test_2023 = pd.DataFrame(data)

# %%
url = 'https://data.wa.gov/resource/h5d9-vgwi.json'

response = requests.get(url)
data = response.json()

school_test_2024 = pd.DataFrame(data)
