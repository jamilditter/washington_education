# %%
import pandas as pd
import requests

# %% [markdown]
# Here, we're loading in all the datasets we're going to use from the State of Washington Open Data API, using Report Card data.

# %%
url = 'https://data.wa.gov/resource/rxjk-6ieq.json?$limit=243167'

response = requests.get(url)
data = response.json()

school_demo_2014to2026 = pd.DataFrame(data)

# %%
school_demo_total_filtered = school_demo_2014to2026[school_demo_2014to2026['gradelevel']=="All Grades"]
school_demo_total_filtered = school_demo_total_filtered[school_demo_total_filtered['schoolname']!="District Total"]
school_demo_total_filtered
# Out:
#        schoolyear organizationlevel    county  \
# 1133      2014-15            School     Adams
# 1141      2014-15            School     Adams
# 1148      2014-15            School     Adams
# 1153      2014-15            School    Asotin
# 1159      2014-15            School    Asotin
# ...           ...               ...       ...
# 243132    2025-26            School    Yakima
# 243135    2025-26            School    Yakima
# 243142    2025-26            School    Yakima
# 243149    2025-26            School    Yakima
# 243162    2025-26             State  Multiple
#
#                                  esdname esdorganizationid districtcode  \
# 1133    Educational Service District 123            100007        01147
# 1141    Educational Service District 123            100007        01147
# 1148    Educational Service District 123            100007        01147
# 1153    Educational Service District 123            100007        02250
# ...

# %% [markdown]
# Here, we're importing the testing data.

# %%
url = 'https://data.wa.gov/resource/292v-tb9r.json?$limit=1000000'

response = requests.get(url)
data = response.json()

school_test_2014to2021_1 = pd.DataFrame(data)

# %%
url = 'https://data.wa.gov/resource/292v-tb9r.json?$limit=1000000&$offset=1000000'

response = requests.get(url)
data = response.json()

school_test_2014to2021_2 = pd.DataFrame(data)

# %%
url = 'https://data.wa.gov/resource/292v-tb9r.json?$limit=500000&$offset=2000000'

response = requests.get(url)
data = response.json()

school_test_2014to2021_2_5 = pd.DataFrame(data)

# %%
url = 'https://data.wa.gov/resource/292v-tb9r.json?$limit=500000&$offset=2500000'

response = requests.get(url)
data = response.json()

school_test_2014to2021_3 = pd.DataFrame(data)

# %%
url = 'https://data.wa.gov/resource/292v-tb9r.json?$limit=1000000&$offset=3000000'

response = requests.get(url)
data = response.json()

school_test_2014to2021_4 = pd.DataFrame(data)

# %%
url = 'https://data.wa.gov/resource/292v-tb9r.json?$limit=1000000&$offset=4000000'

response = requests.get(url)
data = response.json()

school_test_2014to2021_5 = pd.DataFrame(data)

# %%
url = 'https://data.wa.gov/resource/292v-tb9r.json?$limit=1000000&$offset=5000000'

response = requests.get(url)
data = response.json()

school_test_2014to2021_6 = pd.DataFrame(data)

# %%
url = 'https://data.wa.gov/resource/292v-tb9r.json?$limit=1000000&$offset=6000000'

response = requests.get(url)
data = response.json()

school_test_2014to2021_7 = pd.DataFrame(data)

# %%
school_test_2014to2021 = pd.concat([school_test_2014to2021_1, school_test_2014to2021_2, school_test_2014to2021_2_5, school_test_2014to2021_3, 
                                    school_test_2014to2021_4, school_test_2014to2021_5, school_test_2014to2021_6, school_test_2014to2021_7])

# %%
url = 'https://data.wa.gov/resource/xh7m-utwp.json?$limit=782445'

response = requests.get(url)
data = response.json()

school_test_2022 = pd.DataFrame(data)

# %%
url = 'https://data.wa.gov/resource/x73g-mrqp.json?$limit=761859'

response = requests.get(url)
data = response.json()

school_test_2023 = pd.DataFrame(data)

# %%
url = 'https://data.wa.gov/resource/h5d9-vgwi.json?$limit=770128'

response = requests.get(url)
data = response.json()

school_test_2024 = pd.DataFrame(data)

# %% [markdown]
# Unfortunately, this data is formatted differently, so we will have to make some changes to column names to successfully concatenate them together.

# %%
school_test_2014to2021.shape[1]
school_test_2014to2021.columns
# Out:
# Index(['schoolyear', 'organizationlevel', 'county', 'esdname',
#        'esdorganizationid', 'districtcode', 'districtname',
#        'districtorganizationid', 'schoolcode', 'schoolname',
#        'schoolorganizationid', 'currentschooltype', 'studentgrouptype',
#        'studentgroup', 'gradelevel', 'testadministration', 'testsubject',
#        'suppression', 'percentmetstandard', 'dataasof',
#        'count_of_students_expected', 'countmetstandard',
#        'count_of_students_expected_to_test_including_previously_passed',
#        'percentlevel1', 'percentlevel2', 'percentlevel3', 'percentlevel4',
#        'percentmettestedonly', 'percent_no_score'],
#       dtype='str')

# %%
school_test_2014to2021
# Out:
#        schoolyear organizationlevel     county  \
# 0         2021-22            School  Snohomish
# 1         2021-22            School  Snohomish
# 2         2021-22            School  Snohomish
# 3         2021-22            School  Snohomish
# 4         2021-22            School  Snohomish
# ...           ...               ...        ...
# 194465    2020-21          District     Yakima
# 194466    2018-19          District     Yakima
# 194467    2017-18          District     Yakima
# 194468    2016-17          District     Yakima
# 194469    2015-16          District     Yakima
#
#                                            esdname esdorganizationid  \
# 0       Northwest Educational Service District 189            100009
# 1       Northwest Educational Service District 189            100009
# 2       Northwest Educational Service District 189            100009
# 3       Northwest Educational Service District 189            100009
# ...

# %%
school_test_2022.shape[1]
school_test_2022.columns
# Out:
# Index(['schoolyear', 'organizationlevel', 'county', 'esdname',
#        'esdorganizationid', 'districtcode', 'districtname',
#        'districtorganizationid', 'schoolname', 'schoolorganizationid',
#        'studentgrouptype', 'studentgroup', 'gradelevel', 'testadministration',
#        'testsubject', 'dat', 'count_of_students_expected',
#        'count_of_students_expected_to_test_including_previously_passed',
#        'count_consistent_grade_level_knowledge_and_above',
#        'percent_consistent_grade_level_knowledge_and_above', 'percentlevel1',
#        'percentlevel2', 'percentlevel3', 'percentlevel4',
#        'percent_consistent_tested_only', 'percentnoscore',
#        'percentparticipation', 'dataasof', 'schoolcode', 'currentschooltype'],
#       dtype='str')

# %%
school_test_2022
# Out:
#        schoolyear organizationlevel    county      esdname esdorganizationid  \
# 0         2022-23          District   Spokane         NULL              NULL
# 1         2022-23          District   Spokane         NULL              NULL
# 2         2022-23          District   Spokane         NULL              NULL
# 3         2022-23          District   Spokane         NULL              NULL
# 4         2022-23          District   Spokane         NULL              NULL
# ...           ...               ...       ...          ...               ...
# 782440    2022-23             State  Multiple  State Total              NULL
# 782441    2022-23             State  Multiple  State Total              NULL
# 782442    2022-23             State  Multiple  State Total              NULL
# 782443    2022-23             State  Multiple  State Total              NULL
# 782444    2022-23             State  Multiple  State Total              NULL
#
# ...

# %%
school_test_2023.shape[1]
school_test_2023.columns
# Out:
# Index(['schoolyear', 'organizationlevel', 'county', 'esdname', 'districtname',
#        'schoolname', 'studentgrouptype', 'studentgroup', 'gradelevel',
#        'test_administration_group', 'testadministration', 'testsubject', 'dat',
#        'count_of_students_expected', 'count_of_students_expected_1',
#        'count_consistent_grade_level_knowledge_and_above',
#        'percent_consistent_grade_level_knowledge_and_above', 'percentlevel1',
#        'percentlevel2', 'percentlevel3', 'percentlevel4',
#        'percent_met_tested_only', 'percent_no_score', 'percent_participation',
#        'percent_taking_alternative_assessment', 'count_foundational_grade',
#        'percent_foundational_grade', 'dataasof', 'esdorganizationid',
#        'districtcode', 'districtorganizationid', 'schoolcode',
#        'schoolorganizationid', 'currentschooltype'],
#       dtype='str')

# %%
school_test_2023
# Out:
#        schoolyear organizationlevel    county  \
# 0         2023-24             State  Multiple
# 1         2023-24             State  Multiple
# 2         2023-24             State  Multiple
# 3         2023-24             State  Multiple
# 4         2023-24             State  Multiple
# ...           ...               ...       ...
# 761854    2023-24          District    Yakima
# 761855    2023-24          District    Yakima
# 761856    2023-24          District    Yakima
# 761857    2023-24          District    Yakima
# 761858    2023-24          District    Yakima
#
#                                  esdname            districtname  \
# 0                            State Total             State Total
# 1                            State Total             State Total
# 2                            State Total             State Total
# 3                            State Total             State Total
# 4                            State Total             State Total
# ...

# %%
school_test_2024.shape[1]
school_test_2024.columns
# Out:
# Index(['schoolyear', 'organizationlevel', 'county', 'esdname', 'districtname',
#        'schoolname', 'studentgrouptype', 'studentgroup', 'gradelevel',
#        'test_administration_group', 'testadministration', 'testsubject', 'dat',
#        'count_of_students_expected', 'count_of_students_expected_1',
#        'count_consistent_grade_level', 'percent_consistent_grade',
#        'percentlevel1', 'percentlevel2', 'percentlevel3', 'percentlevel4',
#        'percent_consistent_tested', 'percent_no_score',
#        'percent_participation', 'percent_taking_alternative',
#        'count_foundational_grade', 'percent_foundational_grade', 'dataasof',
#        'esdorganizationid', 'districtcode', 'districtorganizationid',
#        'schoolcode', 'schoolorganizationid', 'currentschooltype'],
#       dtype='str')

# %%
school_test_2024
# Out:
#        schoolyear organizationlevel    county  \
# 0         2024-25             State  Multiple
# 1         2024-25             State  Multiple
# 2         2024-25             State  Multiple
# 3         2024-25             State  Multiple
# 4         2024-25             State  Multiple
# ...           ...               ...       ...
# 770123    2024-25          District    Yakima
# 770124    2024-25          District    Yakima
# 770125    2024-25          District    Yakima
# 770126    2024-25          District    Yakima
# 770127    2024-25          District    Yakima
#
#                                  esdname            districtname  \
# 0                            State Total             State Total
# 1                            State Total             State Total
# 2                            State Total             State Total
# 3                            State Total             State Total
# 4                            State Total             State Total
# ...
